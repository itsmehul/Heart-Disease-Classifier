# %%
# Define IAM role
import boto3
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sagemaker
from sagemaker import get_execution_role
from sagemaker.predictor import csv_serializer

# %%
# sagemaker session, role
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()

# S3 bucket name
bucket = sagemaker_session.default_bucket()

# %%
dataset = pd.read_csv("data/heart.csv")
dataset.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
dataset = pd.concat([dataset['target'], dataset.drop(['target'], axis=1)], axis=1) 
dataset.head()
# Out:
#    target  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0       1   63    1   3       145   233    1        0      150      0
# 1       1   37    1   2       130   250    0        1      187      0
# 2       1   41    0   1       130   204    0        0      172      0
# 3       1   56    1   1       120   236    0        1      178      0
# 4       1   57    0   0       120   354    0        1      163      1
#
#    oldpeak  slope  ca  thal
# 0      2.3      0   0     1
# 1      3.5      0   0     2
# 2      1.4      2   0     2
# 3      0.8      2   0     2
# 4      0.6      2   0     2

# %%
dataset=np.random.shuffle(dataset)
train_data = dataset.iloc[:, :243]
test_data = dataset.iloc[:, :60]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 185
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-3687a34a8b6b> in <module>
# ----> 1 dataset=np.random.shuffle(dataset)
#       2 train_data = dataset.iloc[:, :243]
#       3 test_data = dataset.iloc[:, :60]
#
# mtrand.pyx in numpy.random.mtrand.RandomState.shuffle()
#
# mtrand.pyx in numpy.random.mtrand.RandomState.shuffle()
#
# ~/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 185

# %%
# train_data, test_data = np.split(dataset.sample(frac=1, random_state=1729), [int(0.7 * len(dataset)), int(0.9 * len(dataset))])
train_data.to_csv('xgboostdata/train.csv', header=False, index=False)
# validation_data.to_csv('xgboostdata/validation.csv', header=False, index=False)

# %%
# should be the name of directory you created to save your features data
data_dir = 'xgboostdata'

# set prefix, a descriptive name for a directory  
prefix = 'xgb-heart-disease'

# upload all data to S3
input_data = sagemaker_session.upload_data(path=data_dir, bucket=bucket, key_prefix=prefix)

# %%
s3_input_train = sagemaker.s3_input(s3_data='s3://{}/{}/train'.format(bucket, prefix), content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data='s3://{}/{}/validation'.format(bucket, prefix), content_type='csv')

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
sess = sagemaker.Session()
region = boto3.Session().region_name    
smclient = boto3.Session().client('sagemaker')

container = get_image_uri(region, 'xgboost', repo_version='latest')
xgb = sagemaker.estimator.Estimator(container,
                                    role, 
                                    train_instance_count=1, 
                                    train_instance_type='ml.m4.xlarge',
                                    output_path='s3://{}/{}/output'.format(bucket, prefix),
                                    sagemaker_session=sess)
xgb.set_hyperparameters(eta=0.1,
                        objective='binary:logistic',
                        num_round=25)

xgb.fit({'train': s3_input_train})
# Out:
# WARNING:root:There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='0.90-1'. For example:
# 	get_image_uri(region, 'xgboost', '0.90-1').
# 2020-05-03 22:40:27 Starting - Starting the training job...
# 2020-05-03 22:40:29 Starting - Launching requested ML instances...
# 2020-05-03 22:41:26 Starting - Preparing the instances for training......
# 2020-05-03 22:42:18 Downloading - Downloading input data...
# 2020-05-03 22:42:54 Training - Training image download completed. Training in progress..Arguments: train
# [2020-05-03:22:42:55:INFO] Running standalone xgboost training.
# [2020-05-03:22:42:55:INFO] Path /opt/ml/input/data/validation does not exist!
# [2020-05-03:22:42:55:INFO] File size need to be processed in the node: 0.01mb. Available memory size in the node: 8502.84mb
# [2020-05-03:22:42:55:INFO] Determined delimiter of CSV input is ','
# [22:42:55] S3DistributionType set as FullyReplicated
# [22:42:55] 303x13 matrix with 3939 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [0]#011train-error:0.089109
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [1]#011train-error:0.079208
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [2]#011train-error:0.085809
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [3]#011train-error:0.075908
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [4]#011train-error:0.075908
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [5]#011train-error:0.069307
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [6]#011train-error:0.069307
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [7]#011train-error:0.066007
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [8]#011train-error:0.066007
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [9]#011train-error:0.066007
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [10]#011train-error:0.059406
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [11]#011train-error:0.056106
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [12]#011train-error:0.056106
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [13]#011train-error:0.042904
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [14]#011train-error:0.042904
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [15]#011train-error:0.033003
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [16]#011train-error:0.033003
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [17]#011train-error:0.026403
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [18]#011train-error:0.026403
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [19]#011train-error:0.029703
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [20]#011train-error:0.023102
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [21]#011train-error:0.026403
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [22]#011train-error:0.016502
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [23]#011train-error:0.019802
# [22:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=5
# [24]#011train-error:0.019802
#
# 2020-05-03 22:43:07 Uploading - Uploading generated training model
# 2020-05-03 22:43:07 Completed - Training job completed
# Training seconds: 49
# Billable seconds: 49

# %%
xgb_predictor = xgb.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# -------------!

# %%
xgb_predictor.content_type = 'text/csv'
xgb_predictor.serializer = csv_serializer
xgb_predictor.deserializer = None

def predict(data, rows=500):
    split_array = np.array_split(data, int(data.shape[0] / float(rows) + 1))
    predictions = ''
    for array in split_array:
        predictions = ','.join([predictions, xgb_predictor.predict(array).decode('utf-8')])

    return np.fromstring(predictions[1:], sep=',')

predictions = predict(test_data.values[:, 1:])
predictions
# Out:
# array([0.79937273, 0.69498521, 0.9521271 , 0.93001759, 0.78808826,
#        0.88171422, 0.91167301, 0.72530186, 0.86979073, 0.86611092,
#        0.87413114, 0.90548766, 0.94162464, 0.86976618, 0.86020094,
#        0.93265831, 0.78930396, 0.86021256, 0.91693586, 0.90865093,
#        0.70463598, 0.9445619 , 0.88568211, 0.71594715, 0.77080637,
#        0.91416365, 0.85236323, 0.8793174 , 0.87771994, 0.88516223,
#        0.90627211, 0.76254314, 0.94756854, 0.80676991, 0.74551898,
#        0.88661402, 0.94166851, 0.8599785 , 0.88285774, 0.86024761,
#        0.87522215, 0.94339192, 0.61406761, 0.88348287, 0.91607571,
#        0.91607571, 0.94756854, 0.90175515, 0.88888711, 0.93141061,
#        0.94005603, 0.72454208, 0.56433654, 0.91086644, 0.90935522,
#        0.83463389, 0.92428154, 0.90828204, 0.94144791, 0.50621516,
#        0.90669817, 0.79361242, 0.92512584, 0.8410852 , 0.86256105,
#        0.92381734, 0.82321912, 0.95043397, 0.94756854, 0.84082013,
#        0.80968142, 0.86908805, 0.94756854, 0.8692221 , 0.95043397,
#        0.95043397, 0.8779332 , 0.88260192, 0.9384988 , 0.75950843,
#        0.94144791, 0.9201228 , 0.87290686, 0.77684188, 0.85713661,
#        0.86700255, 0.69503433, 0.81826413, 0.92172247, 0.88899553,
#        0.91425472, 0.79135013, 0.88860142, 0.85751134, 0.90948892,
#        0.75761276, 0.73094136, 0.54745686, 0.87601984, 0.86177623,
#        0.80967772, 0.4981584 , 0.83995277, 0.68596643, 0.94756854,
#        0.90833586, 0.66623175, 0.77836561, 0.9521271 , 0.92643094,
#        0.65929949, 0.75115061, 0.74698669, 0.56920975, 0.88629282,
#        0.9521271 , 0.8779332 , 0.82296032, 0.92372936, 0.80533701,
#        0.39064816, 0.85258102, 0.94652915, 0.91914421, 0.92372936,
#        0.95054489, 0.91063428, 0.92483562, 0.95043397, 0.86417252,
#        0.91315591, 0.9485411 , 0.94162464, 0.86273253, 0.94217616,
#        0.93434072, 0.89579052, 0.88501936, 0.58789885, 0.38168031,
#        0.94195122, 0.90667343, 0.95043397, 0.76958919, 0.90789133,
#        0.75636125, 0.7511186 , 0.88845789, 0.94756854, 0.89434814,
#        0.75985587, 0.84106332, 0.66269428, 0.86536598, 0.92906481,
#        0.88339913, 0.94756854, 0.94756854, 0.79341406, 0.89026242,
#        0.92455423, 0.90992367, 0.94053489, 0.88843429, 0.88843429,
#        0.07344162, 0.05693883, 0.14319593, 0.05500194, 0.07944406,
#        0.19762942, 0.51229411, 0.38197717, 0.2827749 , 0.05298692,
#        0.12694354, 0.06978472, 0.29713479, 0.07477769, 0.10308059,
#        0.07549205, 0.07389397, 0.61927414, 0.14897412, 0.07348331,
#        0.14031689, 0.06525928, 0.05298692, 0.29466438, 0.38877916,
#        0.06083103, 0.06040397, 0.06074745, 0.05298692, 0.45595345,
#        0.0739798 , 0.3481065 , 0.22533473, 0.05419345, 0.1146115 ,
#        0.1338678 , 0.05298692, 0.07842156, 0.2324512 , 0.06885119,
#        0.16189732, 0.06055549, 0.06651363, 0.12669685, 0.14563005,
#        0.40253234, 0.05419345, 0.07558145, 0.07666129, 0.06608839,
#        0.06998257, 0.19222589, 0.05990321, 0.05909476, 0.14318673,
#        0.08400764, 0.06914724, 0.1595875 , 0.05826086, 0.0619231 ,
#        0.06947816, 0.12588015, 0.06504296, 0.37432599, 0.15034066,
#        0.65341026, 0.06268238, 0.05298692, 0.06453362, 0.1300181 ,
#        0.10907753, 0.10464068, 0.06054063, 0.12156667, 0.21696359,
#        0.11713556, 0.23817913, 0.10364077, 0.05419345, 0.06581039,
#        0.35086074, 0.08102108, 0.27394754, 0.37055236, 0.18828809,
#        0.06176838, 0.19486542, 0.14642692, 0.22321787, 0.32508519,
#        0.21930048, 0.05298692, 0.07477769, 0.35739031, 0.32913479,
#        0.06928219, 0.15849574, 0.05419345, 0.20962466, 0.19226269,
#        0.133853  , 0.14031267, 0.39933637, 0.06173645, 0.0696661 ,
#        0.07882161, 0.1338113 , 0.47967747, 0.26740953, 0.09492955,
#        0.09200314, 0.06074745, 0.32682714, 0.45550632, 0.0633326 ,
#        0.21715516, 0.42229742, 0.13690214, 0.36903134, 0.063823  ,
#        0.08314906, 0.3819868 , 0.21075779, 0.08598337, 0.06062128,
#        0.15406211, 0.1344908 , 0.09751828, 0.38843414, 0.16366397,
#        0.05747129, 0.34479278, 0.08959314, 0.39610946, 0.24118213,
#        0.06778229, 0.05853498, 0.46336925])

# %%
predictions = [1 if n >= 0.5 else 0 for n in predictions]

# %%
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score
# Show classification report
print(classification_report(test_data.to_numpy()[:,0], predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98       138
#          1.0       0.98      0.98      0.98       165
#
#    micro avg       0.98      0.98      0.98       303
#    macro avg       0.98      0.98      0.98       303
# weighted avg       0.98      0.98      0.98       303
